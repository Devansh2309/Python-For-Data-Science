# %% [markdown]
# <a href="https://colab.research.google.com/github/Devansh2309/Python-For-Data-Science/blob/main/PROJECT_3_COVID_DATA_ANALYSIS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **PROJECT 3:- COVID DATA ANALYSIS**

# %%
import pandas as pd
import numpy as np
data = pd.read_csv('/content/Project - 3(Covid Data).csv')

# %% [markdown]
# Q1:- Show the no. of confirmed cases, Deaths & Recovered Cases in each region?

# %%
data.head(3)
data.groupby('Region')['Confirmed', 'Deaths', 'Recovered'].sum()
# Out:
# <ipython-input-5-701d0ef0969c>:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   data.groupby('Region')['Confirmed', 'Deaths', 'Recovered'].sum()
#                     Confirmed  Deaths  Recovered
# Region
# Afghanistan              1939      60        252
# Albania                   766      30        455
# Algeria                  3848     444       1702
# Andorra                   743      42        423
# Angola                     27       2          7
# ...                       ...     ...        ...
# West Bank and Gaza        344       2         71
# Western Sahara              6       0          5
# Yemen                       6       0          1
# Zambia                     97       3         54
# Zimbabwe                   32       4          5
#
# [187 rows x 3 columns]

# %% [markdown]
# Q2:- Remove all the records where Confirmed Cases is Less than 10.

# %%
data.head(2)
data[~(data.Confirmed<10)]
data
# Out:
#           Date     State          Region  Confirmed  Deaths  Recovered
# 0    4/29/2020       NaN     Afghanistan       1939      60        252
# 1    4/29/2020       NaN         Albania        766      30        455
# 2    4/29/2020       NaN         Algeria       3848     444       1702
# 3    4/29/2020       NaN         Andorra        743      42        423
# 4    4/29/2020       NaN          Angola         27       2          7
# ..         ...       ...             ...        ...     ...        ...
# 316  4/29/2020   Wyoming              US        545       7          0
# 317  4/29/2020  Xinjiang  Mainland China         76       3         73
# 318  4/29/2020     Yukon          Canada         11       0          0
# 319  4/29/2020    Yunnan  Mainland China        185       2        181
# 320  4/29/2020  Zhejiang  Mainland China       1268       1       1263
#
# [304 rows x 6 columns]

# %% [markdown]
# Q3:- In which region, maximum number of confirmed cases were recorded?

# %%
data.head(2)
data.groupby('Region').Confirmed.sum().sort_values(ascending=False)
# Out:
# Region
# US            1039909
# Spain          236899
# Italy          203591
# France         166536
# UK             166432
#                ...
# Seychelles         11
# Burundi            11
# Suriname           10
# Gambia             10
# Holy See           10
# Name: Confirmed, Length: 180, dtype: int64

# %% [markdown]
# Q4:- In which region, maximum number of Deaths cases were recorded?

# %%
data.head(2)
data.groupby('Region').Deaths.sum().sort_values()
# Out:
# Region
# Cambodia                        0
# Seychelles                      0
# Saint Lucia                     0
# Central African Republic        0
# Saint Kitts and Nevis           0
#                             ...
# France                      24121
# Spain                       24275
# UK                          26165
# Italy                       27682
# US                          60967
# Name: Deaths, Length: 180, dtype: int64

# %% [markdown]
# Q5:- How many Confirmed, Deaths and Recovered cases were reported from India till 29th April 2020?

# %%
data.head(10)
data[data.Region=='India']
# Out:
#          Date State Region  Confirmed  Deaths  Recovered
# 74  4/29/2020   NaN  India      33062    1079       8437

# %% [markdown]
# Q6:- (A) Sort the enitre data with respect to No. of Confirmed Cases in ascending order.
#
# (B) Sort the enitre data with respect to No. of Recovered Cases in descending order.

# %%
data.head(2)
data.sort_values(by=['Confirmed'])
# Out:
#           Date      State    Region  Confirmed  Deaths  Recovered
# 156  4/29/2020        NaN  Suriname         10       1          8
# 70   4/29/2020        NaN  Holy See         10       0          2
# 59   4/29/2020        NaN    Gambia         10       1          8
# 318  4/29/2020      Yukon    Canada         11       0          0
# 217  4/29/2020  Greenland   Denmark         11       0         11
# ..         ...        ...       ...        ...     ...        ...
# 57   4/29/2020        NaN    France     165093   24087      48228
# 168  4/29/2020        NaN        UK     165221   26097          0
# 80   4/29/2020        NaN     Italy     203591   27682      71252
# 153  4/29/2020        NaN     Spain     236899   24275     132929
# 265  4/29/2020   New York        US     299691   23477          0
#
# [304 rows x 6 columns]

# %%
data.head(2)
data.sort_values(['Recovered'], ascending = False)
# Out:
#           Date     State          Region  Confirmed  Deaths  Recovered
# 153  4/29/2020       NaN           Spain     236899   24275     132929
# 61   4/29/2020       NaN         Germany     161539    6467     120400
# 76   4/29/2020       NaN            Iran      93657    5957      73791
# 80   4/29/2020       NaN           Italy     203591   27682      71252
# 229  4/29/2020     Hubei  Mainland China      68128    4512      63616
# ..         ...       ...             ...        ...     ...        ...
# 258  4/29/2020    Nevada              US       4934     230          0
# 257  4/29/2020  Nebraska              US       3851      56          0
# 255  4/29/2020   Montana              US        451      16          0
# 254  4/29/2020  Missouri              US       7660     338          0
# 274  4/29/2020      Ohio              US      17303     937          0
#
# [304 rows x 6 columns]
